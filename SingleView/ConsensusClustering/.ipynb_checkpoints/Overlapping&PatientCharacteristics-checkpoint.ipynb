# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from IPython.display import display
import warnings

warnings.filterwarnings("ignore")

# %%
def background_gradient(s, m=None, M=None, cmap='Blues', low=0, high=0.5):
    if m is None:
        m = s.min().min()
    if M is None:
        M = s.max().max()
    rng = M - m
    norm = colors.Normalize(m - (rng * low),
                            M + (rng * high))
    normed = s.apply(norm)

    cm = plt.cm.get_cmap(cmap)
    c = normed.applymap(lambda x: colors.rgb2hex(cm(x)))
    ret = c.applymap(lambda x: 'background-color: %s' % x)
    return ret

def get_characteristic(clinical_view, assignment):
    data = clinical_view.copy()
    data["cluster"] = assignment["assignment"]
    clinical_view["cluster"] = assignment["assignment"].astype(int)
    if -1 in assignment["assignment"].tolist():
        clinical_view = clinical_view[clinical_view['cluster'] != -1]

    cons = [
        "cons05.resp",
        "cons05.cvs",
        "cons05.cns",
        "cons05.ren",
        "cons05.hep",
        "cons05.hem",
    ]
    overall_mean = clinical_view[
        cons
        + ["cons05.score", "ccc.summary", "age.at.bc", "sex", "death.30.bc", "picu"]
    ].mean()

    report = clinical_view.groupby("cluster").mean()[
        cons
        + ["cons05.score", "ccc.summary", "age.at.bc", "sex", "death.30.bc", "picu"]
    ]
    report["size"] = clinical_view.groupby("cluster").size().astype(str)
    report.loc["overall"] = overall_mean.tolist() + [str(len(clinical_view))]
    pd.set_option("display.precision", 3)
    display(report.T)

# %%
data_path = "data/"
score_path = "{}/Clustering_silhouette/".format(data_path)
cdf_path = "{}/CDF plots/".format(data_path)
tsne_path = "{}/TSNEplots/".format(data_path)
KCC_path = "{}/KCC/".format(data_path)

physio_view_original = pd.read_csv("data/PhysioView.csv", index_col=0)
physio_view = pd.read_csv("data/PhysioViewNormalImputed.csv", index_col=0)

contextual_view = pd.read_csv("data/ContextualViewZeroImputed.csv", index_col=0)
clinical_view = pd.concat([physio_view, contextual_view], 1)

data_episode = pd.read_csv('../olinks/spss_mlcb_olink_episode.csv', index_col=0)
data_episode = data_episode.loc[clinical_view.index]

clinical_view[["death.30.bc", "picu"]] = data_episode[["death.30.bc", "picu"]].replace(['no', 'yes'], [0, 1])

# %%
configs = [
    ["clinical", 4, "ConsensusKMeans"],
    ["contextual", 5, "ConsensusKMeans"],
    ["physio", 3, "DBSCAN"],
    ["proteome", 3, "ConsensusKMeans"],
    ["proteome", 4, "ConsensusKMeans"],
]

# %% [markdown]
# # cluster overlapping

# %%
for i in range(len(configs)):
    for j in range(len(configs)):
        if j > i:
            view, KCC_space, method1 = configs[i]
            assignment1 = pd.read_csv(
                "{}/{}_{}_view_KCC_{}_assignments.csv".format(
                    score_path, method1, view, KCC_space
                ),
                index_col=0,
            )
            if method1 == "DBSCAN":
                assignment1["assignment"] = assignment1["assignment"] + 1
                assignment1 = assignment1[assignment1["assignment"] != 0]

            view, KCC_space, method2 = configs[j]
            assignment2 = pd.read_csv(
                "{}/{}_{}_view_KCC_{}_assignments.csv".format(
                    score_path, method2, view, KCC_space
                ),
                index_col=0,
            )
            if method2 == "DBSCAN":
                assignment2["assignment"] = assignment2["assignment"] + 1
                assignment2 = assignment2[assignment2["assignment"] != 0]

            agreement_mat = pd.DataFrame(
                index=[
                    "{} {}".format(method1, i)
                    for i in sorted(assignment1["assignment"].unique())
                ],
                columns=[
                    "{} {}".format(method2, i)
                    for i in sorted(assignment2["assignment"].unique())
                ],
            )
            print(
                "{} view, KCC {}, {} / {} view, KCC {}, {}".format(
                    *(configs[i] + configs[j])
                )
            )

            for cluster1 in sorted(assignment1["assignment"].unique()):
                for cluster2 in sorted(assignment2["assignment"].unique()):
                    index_1 = assignment1[assignment1["assignment"] == cluster1].index
                    index_2 = assignment2[assignment2["assignment"] == cluster2].index
                    len_overlap = len(list(set(index_1).intersection(set(index_2))))
                    len_union = len(set(index_1).union(set(index_2)))
                    agreement_mat.loc[
                        "{} {}".format(method1, cluster1), "{} {}".format(method2, cluster2)
                    ] = (len_overlap / len_union)
            agreement_mat = agreement_mat.astype(float)
            display(
                agreement_mat.style.set_precision(3).apply(
                    background_gradient, axis=None
                )
            )
            print("-" * 80)
# Out:
# clinical view, KCC 4, ConsensusKMeans / contextual view, KCC 5, ConsensusKMeans
# <style type="text/css">
# #T_e8eb2_row0_col0 {
#   background-color: #b8d5ea;
# }
# #T_e8eb2_row0_col1 {
#   background-color: #3a8ac2;
# }
# #T_e8eb2_row0_col2 {
#   background-color: #a6cee4;
# }
# #T_e8eb2_row0_col3 {
#   background-color: #e0ecf8;
# }
# #T_e8eb2_row0_col4 {
#   background-color: #a0cbe2;
# }
# #T_e8eb2_row1_col0 {
#   background-color: #a4cce3;
# }
# #T_e8eb2_row1_col1 {
#   background-color: #c7dcef;
# }
# #T_e8eb2_row1_col2 {
#   background-color: #d0e1f2;
# }
# #T_e8eb2_row1_col3 {
#   background-color: #8dc1dd;
# }
# #T_e8eb2_row1_col4 {
#   background-color: #c7dbef;
# }
# #T_e8eb2_row2_col0 {
#   background-color: #b7d4ea;
# }
# #T_e8eb2_row2_col1 {
#   background-color: #edf4fc;
# }
# #T_e8eb2_row2_col2, #T_e8eb2_row3_col2 {
#   background-color: #f7fbff;
# }
# #T_e8eb2_row2_col3 {
#   background-color: #d5e5f4;
# }
# #T_e8eb2_row2_col4 {
#   background-color: #aacfe5;
# }
# #T_e8eb2_row3_col0 {
#   background-color: #caddf0;
# }
# #T_e8eb2_row3_col1 {
#   background-color: #f2f7fd;
# }
# #T_e8eb2_row3_col3 {
#   background-color: #3787c0;
# }
# #T_e8eb2_row3_col4 {
#   background-color: #e3eef8;
# }
# </style>
# <table id="T_e8eb2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#       <th class="col_heading level0 col3" >ConsensusKMeans 4</th>
#       <th class="col_heading level0 col4" >ConsensusKMeans 5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8eb2_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_e8eb2_row0_col0" class="data row0 col0" >0.136</td>
#       <td id="T_e8eb2_row0_col1" class="data row0 col1" >0.289</td>
#       <td id="T_e8eb2_row0_col2" class="data row0 col2" >0.159</td>
#       <td id="T_e8eb2_row0_col3" class="data row0 col3" >0.059</td>
#       <td id="T_e8eb2_row0_col4" class="data row0 col4" >0.167</td>
#     </tr>
#     <tr>
#       <th id="T_e8eb2_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_e8eb2_row1_col0" class="data row1 col0" >0.163</td>
#       <td id="T_e8eb2_row1_col1" class="data row1 col1" >0.113</td>
#       <td id="T_e8eb2_row1_col2" class="data row1 col2" >0.096</td>
#       <td id="T_e8eb2_row1_col3" class="data row1 col3" >0.188</td>
#       <td id="T_e8eb2_row1_col4" class="data row1 col4" >0.115</td>
#     </tr>
#     <tr>
#       <th id="T_e8eb2_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_e8eb2_row2_col0" class="data row2 col0" >0.137</td>
#       <td id="T_e8eb2_row2_col1" class="data row2 col1" >0.031</td>
#       <td id="T_e8eb2_row2_col2" class="data row2 col2" >0.011</td>
#       <td id="T_e8eb2_row2_col3" class="data row2 col3" >0.083</td>
#       <td id="T_e8eb2_row2_col4" class="data row2 col4" >0.153</td>
#     </tr>
#     <tr>
#       <th id="T_e8eb2_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_e8eb2_row3_col0" class="data row3 col0" >0.109</td>
#       <td id="T_e8eb2_row3_col1" class="data row3 col1" >0.022</td>
#       <td id="T_e8eb2_row3_col2" class="data row3 col2" >0.010</td>
#       <td id="T_e8eb2_row3_col3" class="data row3 col3" >0.294</td>
#       <td id="T_e8eb2_row3_col4" class="data row3 col4" >0.053</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# clinical view, KCC 4, ConsensusKMeans / physio view, KCC 3, DBSCAN
# <style type="text/css">
# #T_91a73_row0_col0 {
#   background-color: #dceaf6;
# }
# #T_91a73_row0_col1, #T_91a73_row1_col0 {
#   background-color: #b0d2e7;
# }
# #T_91a73_row0_col2 {
#   background-color: #dae8f6;
# }
# #T_91a73_row0_col3 {
#   background-color: #f5fafe;
# }
# #T_91a73_row1_col1 {
#   background-color: #dfecf7;
# }
# #T_91a73_row1_col2 {
#   background-color: #eaf3fb;
# }
# #T_91a73_row1_col3 {
#   background-color: #f2f8fd;
# }
# #T_91a73_row2_col0 {
#   background-color: #f4f9fe;
# }
# #T_91a73_row2_col1, #T_91a73_row3_col3 {
#   background-color: #f7fbff;
# }
# #T_91a73_row2_col2 {
#   background-color: #f5f9fe;
# }
# #T_91a73_row2_col3 {
#   background-color: #3787c0;
# }
# #T_91a73_row3_col0 {
#   background-color: #edf4fc;
# }
# #T_91a73_row3_col1 {
#   background-color: #e3eef9;
# }
# #T_91a73_row3_col2 {
#   background-color: #caddf0;
# }
# </style>
# <table id="T_91a73_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DBSCAN 1</th>
#       <th class="col_heading level0 col1" >DBSCAN 2</th>
#       <th class="col_heading level0 col2" >DBSCAN 3</th>
#       <th class="col_heading level0 col3" >DBSCAN 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91a73_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_91a73_row0_col0" class="data row0 col0" >0.158</td>
#       <td id="T_91a73_row0_col1" class="data row0 col1" >0.370</td>
#       <td id="T_91a73_row0_col2" class="data row0 col2" >0.170</td>
#       <td id="T_91a73_row0_col3" class="data row0 col3" >0.010</td>
#     </tr>
#     <tr>
#       <th id="T_91a73_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_91a73_row1_col0" class="data row1 col0" >0.367</td>
#       <td id="T_91a73_row1_col1" class="data row1 col1" >0.137</td>
#       <td id="T_91a73_row1_col2" class="data row1 col2" >0.077</td>
#       <td id="T_91a73_row1_col3" class="data row1 col3" >0.031</td>
#     </tr>
#     <tr>
#       <th id="T_91a73_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_91a73_row2_col0" class="data row2 col0" >0.019</td>
#       <td id="T_91a73_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_91a73_row2_col2" class="data row2 col2" >0.016</td>
#       <td id="T_91a73_row2_col3" class="data row2 col3" >0.772</td>
#     </tr>
#     <tr>
#       <th id="T_91a73_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_91a73_row3_col0" class="data row3 col0" >0.062</td>
#       <td id="T_91a73_row3_col1" class="data row3 col1" >0.114</td>
#       <td id="T_91a73_row3_col2" class="data row3 col2" >0.268</td>
#       <td id="T_91a73_row3_col3" class="data row3 col3" >0.000</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# clinical view, KCC 4, ConsensusKMeans / proteome view, KCC 3, ConsensusKMeans
# <style type="text/css">
# #T_e3943_row0_col0 {
#   background-color: #66abd4;
# }
# #T_e3943_row0_col1 {
#   background-color: #3787c0;
# }
# #T_e3943_row0_col2 {
#   background-color: #c7dbef;
# }
# #T_e3943_row1_col0 {
#   background-color: #89bedc;
# }
# #T_e3943_row1_col1, #T_e3943_row2_col2 {
#   background-color: #94c4df;
# }
# #T_e3943_row1_col2 {
#   background-color: #c4daee;
# }
# #T_e3943_row2_col0, #T_e3943_row3_col1 {
#   background-color: #ecf4fb;
# }
# #T_e3943_row2_col1 {
#   background-color: #f7fbff;
# }
# #T_e3943_row3_col0 {
#   background-color: #a9cfe5;
# }
# #T_e3943_row3_col2 {
#   background-color: #e3eef8;
# }
# </style>
# <table id="T_e3943_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3943_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_e3943_row0_col0" class="data row0 col0" >0.239</td>
#       <td id="T_e3943_row0_col1" class="data row0 col1" >0.293</td>
#       <td id="T_e3943_row0_col2" class="data row0 col2" >0.145</td>
#     </tr>
#     <tr>
#       <th id="T_e3943_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_e3943_row1_col0" class="data row1 col0" >0.209</td>
#       <td id="T_e3943_row1_col1" class="data row1 col1" >0.199</td>
#       <td id="T_e3943_row1_col2" class="data row1 col2" >0.149</td>
#     </tr>
#     <tr>
#       <th id="T_e3943_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_e3943_row2_col0" class="data row2 col0" >0.079</td>
#       <td id="T_e3943_row2_col1" class="data row2 col1" >0.058</td>
#       <td id="T_e3943_row2_col2" class="data row2 col2" >0.200</td>
#     </tr>
#     <tr>
#       <th id="T_e3943_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_e3943_row3_col0" class="data row3 col0" >0.179</td>
#       <td id="T_e3943_row3_col1" class="data row3 col1" >0.079</td>
#       <td id="T_e3943_row3_col2" class="data row3 col2" >0.095</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# clinical view, KCC 4, ConsensusKMeans / proteome view, KCC 4, ConsensusKMeans
# <style type="text/css">
# #T_4536b_row0_col0 {
#   background-color: #bad6eb;
# }
# #T_4536b_row0_col1 {
#   background-color: #3787c0;
# }
# #T_4536b_row0_col2 {
#   background-color: #a3cce3;
# }
# #T_4536b_row0_col3 {
#   background-color: #7cb7da;
# }
# #T_4536b_row1_col0 {
#   background-color: #57a0ce;
# }
# #T_4536b_row1_col1 {
#   background-color: #81badb;
# }
# #T_4536b_row1_col2 {
#   background-color: #a8cee4;
# }
# #T_4536b_row1_col3 {
#   background-color: #e0ecf8;
# }
# #T_4536b_row2_col0 {
#   background-color: #d4e4f4;
# }
# #T_4536b_row2_col1 {
#   background-color: #deebf7;
# }
# #T_4536b_row2_col2 {
#   background-color: #8dc1dd;
# }
# #T_4536b_row2_col3 {
#   background-color: #f7fbff;
# }
# #T_4536b_row3_col0 {
#   background-color: #d9e7f5;
# }
# #T_4536b_row3_col1 {
#   background-color: #ddeaf7;
# }
# #T_4536b_row3_col2 {
#   background-color: #d6e6f4;
# }
# #T_4536b_row3_col3 {
#   background-color: #72b2d8;
# }
# </style>
# <table id="T_4536b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#       <th class="col_heading level0 col3" >ConsensusKMeans 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4536b_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_4536b_row0_col0" class="data row0 col0" >0.131</td>
#       <td id="T_4536b_row0_col1" class="data row0 col1" >0.261</td>
#       <td id="T_4536b_row0_col2" class="data row0 col2" >0.157</td>
#       <td id="T_4536b_row0_col3" class="data row0 col3" >0.190</td>
#     </tr>
#     <tr>
#       <th id="T_4536b_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_4536b_row1_col0" class="data row1 col0" >0.225</td>
#       <td id="T_4536b_row1_col1" class="data row1 col1" >0.186</td>
#       <td id="T_4536b_row1_col2" class="data row1 col2" >0.151</td>
#       <td id="T_4536b_row1_col3" class="data row1 col3" >0.072</td>
#     </tr>
#     <tr>
#       <th id="T_4536b_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_4536b_row2_col0" class="data row2 col0" >0.093</td>
#       <td id="T_4536b_row2_col1" class="data row2 col1" >0.076</td>
#       <td id="T_4536b_row2_col2" class="data row2 col2" >0.175</td>
#       <td id="T_4536b_row2_col3" class="data row2 col3" >0.032</td>
#     </tr>
#     <tr>
#       <th id="T_4536b_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_4536b_row3_col0" class="data row3 col0" >0.086</td>
#       <td id="T_4536b_row3_col1" class="data row3 col1" >0.077</td>
#       <td id="T_4536b_row3_col2" class="data row3 col2" >0.089</td>
#       <td id="T_4536b_row3_col3" class="data row3 col3" >0.198</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# contextual view, KCC 5, ConsensusKMeans / physio view, KCC 3, DBSCAN
# <style type="text/css">
# #T_bd597_row0_col0 {
#   background-color: #b0d2e7;
# }
# #T_bd597_row0_col1 {
#   background-color: #aacfe5;
# }
# #T_bd597_row0_col2 {
#   background-color: #b8d5ea;
# }
# #T_bd597_row0_col3, #T_bd597_row2_col1 {
#   background-color: #bcd7eb;
# }
# #T_bd597_row1_col0 {
#   background-color: #cde0f1;
# }
# #T_bd597_row1_col1 {
#   background-color: #3787c0;
# }
# #T_bd597_row1_col2 {
#   background-color: #dfebf7;
# }
# #T_bd597_row1_col3 {
#   background-color: #e8f1fa;
# }
# #T_bd597_row2_col0 {
#   background-color: #a5cde3;
# }
# #T_bd597_row2_col2 {
#   background-color: #f7fbff;
# }
# #T_bd597_row2_col3 {
#   background-color: #f6faff;
# }
# #T_bd597_row3_col0 {
#   background-color: #b2d2e8;
# }
# #T_bd597_row3_col1 {
#   background-color: #cee0f2;
# }
# #T_bd597_row3_col2 {
#   background-color: #84bcdb;
# }
# #T_bd597_row3_col3 {
#   background-color: #c3daee;
# }
# #T_bd597_row4_col0 {
#   background-color: #b3d3e8;
# }
# #T_bd597_row4_col1 {
#   background-color: #dbe9f6;
# }
# #T_bd597_row4_col2 {
#   background-color: #9ac8e0;
# }
# #T_bd597_row4_col3 {
#   background-color: #bfd8ed;
# }
# </style>
# <table id="T_bd597_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >DBSCAN 1</th>
#       <th class="col_heading level0 col1" >DBSCAN 2</th>
#       <th class="col_heading level0 col2" >DBSCAN 3</th>
#       <th class="col_heading level0 col3" >DBSCAN 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd597_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_bd597_row0_col0" class="data row0 col0" >0.141</td>
#       <td id="T_bd597_row0_col1" class="data row0 col1" >0.149</td>
#       <td id="T_bd597_row0_col2" class="data row0 col2" >0.132</td>
#       <td id="T_bd597_row0_col3" class="data row0 col3" >0.127</td>
#     </tr>
#     <tr>
#       <th id="T_bd597_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_bd597_row1_col0" class="data row1 col0" >0.097</td>
#       <td id="T_bd597_row1_col1" class="data row1 col1" >0.287</td>
#       <td id="T_bd597_row1_col2" class="data row1 col2" >0.059</td>
#       <td id="T_bd597_row1_col3" class="data row1 col3" >0.039</td>
#     </tr>
#     <tr>
#       <th id="T_bd597_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_bd597_row2_col0" class="data row2 col0" >0.157</td>
#       <td id="T_bd597_row2_col1" class="data row2 col1" >0.127</td>
#       <td id="T_bd597_row2_col2" class="data row2 col2" >0.008</td>
#       <td id="T_bd597_row2_col3" class="data row2 col3" >0.011</td>
#     </tr>
#     <tr>
#       <th id="T_bd597_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_bd597_row3_col0" class="data row3 col0" >0.140</td>
#       <td id="T_bd597_row3_col1" class="data row3 col1" >0.095</td>
#       <td id="T_bd597_row3_col2" class="data row3 col2" >0.192</td>
#       <td id="T_bd597_row3_col3" class="data row3 col3" >0.116</td>
#     </tr>
#     <tr>
#       <th id="T_bd597_level0_row4" class="row_heading level0 row4" >ConsensusKMeans 5</th>
#       <td id="T_bd597_row4_col0" class="data row4 col0" >0.139</td>
#       <td id="T_bd597_row4_col1" class="data row4 col1" >0.068</td>
#       <td id="T_bd597_row4_col2" class="data row4 col2" >0.169</td>
#       <td id="T_bd597_row4_col3" class="data row4 col3" >0.122</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# contextual view, KCC 5, ConsensusKMeans / proteome view, KCC 3, ConsensusKMeans
# <style type="text/css">
# #T_c79fd_row0_col0 {
#   background-color: #bdd7ec;
# }
# #T_c79fd_row0_col1 {
#   background-color: #89bedc;
# }
# #T_c79fd_row0_col2 {
#   background-color: #5ca4d0;
# }
# #T_c79fd_row1_col0 {
#   background-color: #6fb0d7;
# }
# #T_c79fd_row1_col1 {
#   background-color: #b9d6ea;
# }
# #T_c79fd_row1_col2 {
#   background-color: #b7d4ea;
# }
# #T_c79fd_row2_col0 {
#   background-color: #d8e7f5;
# }
# #T_c79fd_row2_col1 {
#   background-color: #79b5d9;
# }
# #T_c79fd_row2_col2 {
#   background-color: #f7fbff;
# }
# #T_c79fd_row3_col0 {
#   background-color: #3787c0;
# }
# #T_c79fd_row3_col1 {
#   background-color: #ccdff1;
# }
# #T_c79fd_row3_col2 {
#   background-color: #add0e6;
# }
# #T_c79fd_row4_col0 {
#   background-color: #abd0e6;
# }
# #T_c79fd_row4_col1 {
#   background-color: #92c4de;
# }
# #T_c79fd_row4_col2 {
#   background-color: #aed1e7;
# }
# </style>
# <table id="T_c79fd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c79fd_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_c79fd_row0_col0" class="data row0 col0" >0.118</td>
#       <td id="T_c79fd_row0_col1" class="data row0 col1" >0.168</td>
#       <td id="T_c79fd_row0_col2" class="data row0 col2" >0.209</td>
#     </tr>
#     <tr>
#       <th id="T_c79fd_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_c79fd_row1_col0" class="data row1 col0" >0.191</td>
#       <td id="T_c79fd_row1_col1" class="data row1 col1" >0.122</td>
#       <td id="T_c79fd_row1_col2" class="data row1 col2" >0.124</td>
#     </tr>
#     <tr>
#       <th id="T_c79fd_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_c79fd_row2_col0" class="data row2 col0" >0.075</td>
#       <td id="T_c79fd_row2_col1" class="data row2 col1" >0.182</td>
#       <td id="T_c79fd_row2_col2" class="data row2 col2" >0.021</td>
#     </tr>
#     <tr>
#       <th id="T_c79fd_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_c79fd_row3_col0" class="data row3 col0" >0.251</td>
#       <td id="T_c79fd_row3_col1" class="data row3 col1" >0.098</td>
#       <td id="T_c79fd_row3_col2" class="data row3 col2" >0.135</td>
#     </tr>
#     <tr>
#       <th id="T_c79fd_level0_row4" class="row_heading level0 row4" >ConsensusKMeans 5</th>
#       <td id="T_c79fd_row4_col0" class="data row4 col0" >0.136</td>
#       <td id="T_c79fd_row4_col1" class="data row4 col1" >0.161</td>
#       <td id="T_c79fd_row4_col2" class="data row4 col2" >0.134</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# contextual view, KCC 5, ConsensusKMeans / proteome view, KCC 4, ConsensusKMeans
# <style type="text/css">
# #T_2bc57_row0_col0 {
#   background-color: #bcd7eb;
# }
# #T_2bc57_row0_col1 {
#   background-color: #5ca4d0;
# }
# #T_2bc57_row0_col2 {
#   background-color: #3787c0;
# }
# #T_2bc57_row0_col3 {
#   background-color: #d9e7f5;
# }
# #T_2bc57_row1_col0 {
#   background-color: #74b3d8;
# }
# #T_2bc57_row1_col1, #T_2bc57_row4_col3 {
#   background-color: #a4cce3;
# }
# #T_2bc57_row1_col2 {
#   background-color: #95c5df;
# }
# #T_2bc57_row1_col3 {
#   background-color: #bad6eb;
# }
# #T_2bc57_row2_col0 {
#   background-color: #d1e2f3;
# }
# #T_2bc57_row2_col1 {
#   background-color: #68acd5;
# }
# #T_2bc57_row2_col2 {
#   background-color: #f7fbff;
# }
# #T_2bc57_row2_col3 {
#   background-color: #dfebf7;
# }
# #T_2bc57_row3_col0 {
#   background-color: #65aad4;
# }
# #T_2bc57_row3_col1 {
#   background-color: #c2d9ee;
# }
# #T_2bc57_row3_col2 {
#   background-color: #abd0e6;
# }
# #T_2bc57_row3_col3 {
#   background-color: #3f8fc5;
# }
# #T_2bc57_row4_col0 {
#   background-color: #c3daee;
# }
# #T_2bc57_row4_col1 {
#   background-color: #84bcdb;
# }
# #T_2bc57_row4_col2 {
#   background-color: #92c4de;
# }
# </style>
# <table id="T_2bc57_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#       <th class="col_heading level0 col3" >ConsensusKMeans 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bc57_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_2bc57_row0_col0" class="data row0 col0" >0.103</td>
#       <td id="T_2bc57_row0_col1" class="data row0 col1" >0.172</td>
#       <td id="T_2bc57_row0_col2" class="data row0 col2" >0.204</td>
#       <td id="T_2bc57_row0_col3" class="data row0 col3" >0.070</td>
#     </tr>
#     <tr>
#       <th id="T_2bc57_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_2bc57_row1_col0" class="data row1 col0" >0.154</td>
#       <td id="T_2bc57_row1_col1" class="data row1 col1" >0.123</td>
#       <td id="T_2bc57_row1_col2" class="data row1 col2" >0.133</td>
#       <td id="T_2bc57_row1_col3" class="data row1 col3" >0.104</td>
#     </tr>
#     <tr>
#       <th id="T_2bc57_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_2bc57_row2_col0" class="data row2 col0" >0.080</td>
#       <td id="T_2bc57_row2_col1" class="data row2 col1" >0.163</td>
#       <td id="T_2bc57_row2_col2" class="data row2 col2" >0.029</td>
#       <td id="T_2bc57_row2_col3" class="data row2 col3" >0.061</td>
#     </tr>
#     <tr>
#       <th id="T_2bc57_level0_row3" class="row_heading level0 row3" >ConsensusKMeans 4</th>
#       <td id="T_2bc57_row3_col0" class="data row3 col0" >0.165</td>
#       <td id="T_2bc57_row3_col1" class="data row3 col1" >0.098</td>
#       <td id="T_2bc57_row3_col2" class="data row3 col2" >0.117</td>
#       <td id="T_2bc57_row3_col3" class="data row3 col3" >0.196</td>
#     </tr>
#     <tr>
#       <th id="T_2bc57_level0_row4" class="row_heading level0 row4" >ConsensusKMeans 5</th>
#       <td id="T_2bc57_row4_col0" class="data row4 col0" >0.097</td>
#       <td id="T_2bc57_row4_col1" class="data row4 col1" >0.145</td>
#       <td id="T_2bc57_row4_col2" class="data row4 col2" >0.135</td>
#       <td id="T_2bc57_row4_col3" class="data row4 col3" >0.122</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# physio view, KCC 3, DBSCAN / proteome view, KCC 3, ConsensusKMeans
# <style type="text/css">
# #T_1ba99_row0_col0 {
#   background-color: #9cc9e1;
# }
# #T_1ba99_row0_col1 {
#   background-color: #81badb;
# }
# #T_1ba99_row0_col2 {
#   background-color: #cddff1;
# }
# #T_1ba99_row1_col0 {
#   background-color: #b0d2e7;
# }
# #T_1ba99_row1_col1 {
#   background-color: #3787c0;
# }
# #T_1ba99_row1_col2 {
#   background-color: #cfe1f2;
# }
# #T_1ba99_row2_col0 {
#   background-color: #4b98ca;
# }
# #T_1ba99_row2_col1 {
#   background-color: #f6faff;
# }
# #T_1ba99_row2_col2 {
#   background-color: #d6e6f4;
# }
# #T_1ba99_row3_col0 {
#   background-color: #e6f0f9;
# }
# #T_1ba99_row3_col1 {
#   background-color: #f7fbff;
# }
# #T_1ba99_row3_col2 {
#   background-color: #9fcae1;
# }
# </style>
# <table id="T_1ba99_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ba99_level0_row0" class="row_heading level0 row0" >DBSCAN 1</th>
#       <td id="T_1ba99_row0_col0" class="data row0 col0" >0.192</td>
#       <td id="T_1ba99_row0_col1" class="data row0 col1" >0.216</td>
#       <td id="T_1ba99_row0_col2" class="data row0 col2" >0.134</td>
#     </tr>
#     <tr>
#       <th id="T_1ba99_level0_row1" class="row_heading level0 row1" >DBSCAN 2</th>
#       <td id="T_1ba99_row1_col0" class="data row1 col0" >0.171</td>
#       <td id="T_1ba99_row1_col1" class="data row1 col1" >0.293</td>
#       <td id="T_1ba99_row1_col2" class="data row1 col2" >0.131</td>
#     </tr>
#     <tr>
#       <th id="T_1ba99_level0_row2" class="row_heading level0 row2" >DBSCAN 3</th>
#       <td id="T_1ba99_row2_col0" class="data row2 col0" >0.267</td>
#       <td id="T_1ba99_row2_col1" class="data row2 col1" >0.060</td>
#       <td id="T_1ba99_row2_col2" class="data row2 col2" >0.117</td>
#     </tr>
#     <tr>
#       <th id="T_1ba99_level0_row3" class="row_heading level0 row3" >DBSCAN 4</th>
#       <td id="T_1ba99_row3_col0" class="data row3 col0" >0.089</td>
#       <td id="T_1ba99_row3_col1" class="data row3 col1" >0.058</td>
#       <td id="T_1ba99_row3_col2" class="data row3 col2" >0.189</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# physio view, KCC 3, DBSCAN / proteome view, KCC 4, ConsensusKMeans
# <style type="text/css">
# #T_f70d9_row0_col0 {
#   background-color: #9fcae1;
# }
# #T_f70d9_row0_col1 {
#   background-color: #b4d3e9;
# }
# #T_f70d9_row0_col2 {
#   background-color: #cbdef1;
# }
# #T_f70d9_row0_col3, #T_f70d9_row3_col3 {
#   background-color: #f7fbff;
# }
# #T_f70d9_row1_col0 {
#   background-color: #d4e4f4;
# }
# #T_f70d9_row1_col1 {
#   background-color: #85bcdc;
# }
# #T_f70d9_row1_col2 {
#   background-color: #cddff1;
# }
# #T_f70d9_row1_col3 {
#   background-color: #dce9f6;
# }
# #T_f70d9_row2_col0 {
#   background-color: #eef5fc;
# }
# #T_f70d9_row2_col1 {
#   background-color: #f2f8fd;
# }
# #T_f70d9_row2_col2 {
#   background-color: #deebf7;
# }
# #T_f70d9_row2_col3 {
#   background-color: #3787c0;
# }
# #T_f70d9_row3_col0 {
#   background-color: #dfecf7;
# }
# #T_f70d9_row3_col1 {
#   background-color: #e9f2fa;
# }
# #T_f70d9_row3_col2 {
#   background-color: #c7dcef;
# }
# </style>
# <table id="T_f70d9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#       <th class="col_heading level0 col3" >ConsensusKMeans 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f70d9_level0_row0" class="row_heading level0 row0" >DBSCAN 1</th>
#       <td id="T_f70d9_row0_col0" class="data row0 col0" >0.232</td>
#       <td id="T_f70d9_row0_col1" class="data row0 col1" >0.197</td>
#       <td id="T_f70d9_row0_col2" class="data row0 col2" >0.155</td>
#       <td id="T_f70d9_row0_col3" class="data row0 col3" >0.038</td>
#     </tr>
#     <tr>
#       <th id="T_f70d9_level0_row1" class="row_heading level0 row1" >DBSCAN 2</th>
#       <td id="T_f70d9_row1_col0" class="data row1 col0" >0.131</td>
#       <td id="T_f70d9_row1_col1" class="data row1 col1" >0.263</td>
#       <td id="T_f70d9_row1_col2" class="data row1 col2" >0.149</td>
#       <td id="T_f70d9_row1_col3" class="data row1 col3" >0.109</td>
#     </tr>
#     <tr>
#       <th id="T_f70d9_level0_row2" class="row_heading level0 row2" >DBSCAN 3</th>
#       <td id="T_f70d9_row2_col0" class="data row2 col0" >0.062</td>
#       <td id="T_f70d9_row2_col1" class="data row2 col1" >0.052</td>
#       <td id="T_f70d9_row2_col2" class="data row2 col2" >0.105</td>
#       <td id="T_f70d9_row2_col3" class="data row2 col3" >0.383</td>
#     </tr>
#     <tr>
#       <th id="T_f70d9_level0_row3" class="row_heading level0 row3" >DBSCAN 4</th>
#       <td id="T_f70d9_row3_col0" class="data row3 col0" >0.101</td>
#       <td id="T_f70d9_row3_col1" class="data row3 col1" >0.075</td>
#       <td id="T_f70d9_row3_col2" class="data row3 col2" >0.164</td>
#       <td id="T_f70d9_row3_col3" class="data row3 col3" >0.040</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------
# proteome view, KCC 3, ConsensusKMeans / proteome view, KCC 4, ConsensusKMeans
# <style type="text/css">
# #T_86103_row0_col0 {
#   background-color: #89bedc;
# }
# #T_86103_row0_col1, #T_86103_row0_col2, #T_86103_row1_col0 {
#   background-color: #f7fbff;
# }
# #T_86103_row0_col3 {
#   background-color: #aed1e7;
# }
# #T_86103_row1_col1 {
#   background-color: #3787c0;
# }
# #T_86103_row1_col2 {
#   background-color: #f1f7fd;
# }
# #T_86103_row1_col3 {
#   background-color: #f3f8fe;
# }
# #T_86103_row2_col0, #T_86103_row2_col3 {
#   background-color: #f5f9fe;
# }
# #T_86103_row2_col1 {
#   background-color: #f4f9fe;
# }
# #T_86103_row2_col2 {
#   background-color: #4191c6;
# }
# </style>
# <table id="T_86103_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ConsensusKMeans 1</th>
#       <th class="col_heading level0 col1" >ConsensusKMeans 2</th>
#       <th class="col_heading level0 col2" >ConsensusKMeans 3</th>
#       <th class="col_heading level0 col3" >ConsensusKMeans 4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86103_level0_row0" class="row_heading level0 row0" >ConsensusKMeans 1</th>
#       <td id="T_86103_row0_col0" class="data row0 col0" >0.534</td>
#       <td id="T_86103_row0_col1" class="data row0 col1" >0.004</td>
#       <td id="T_86103_row0_col2" class="data row0 col2" >0.004</td>
#       <td id="T_86103_row0_col3" class="data row0 col3" >0.410</td>
#     </tr>
#     <tr>
#       <th id="T_86103_level0_row1" class="row_heading level0 row1" >ConsensusKMeans 2</th>
#       <td id="T_86103_row1_col0" class="data row1 col0" >0.005</td>
#       <td id="T_86103_row1_col1" class="data row1 col1" >0.832</td>
#       <td id="T_86103_row1_col2" class="data row1 col2" >0.046</td>
#       <td id="T_86103_row1_col3" class="data row1 col3" >0.030</td>
#     </tr>
#     <tr>
#       <th id="T_86103_level0_row2" class="row_heading level0 row2" >ConsensusKMeans 3</th>
#       <td id="T_86103_row2_col0" class="data row2 col0" >0.021</td>
#       <td id="T_86103_row2_col1" class="data row2 col1" >0.023</td>
#       <td id="T_86103_row2_col2" class="data row2 col2" >0.784</td>
#       <td id="T_86103_row2_col3" class="data row2 col3" >0.023</td>
#     </tr>
#   </tbody>
# </table>
# --------------------------------------------------------------------------------

# %%
view, KCC_space, method1 = configs[2]
assignment1 = pd.read_csv(
    "{}/{}_{}_view_KCC_{}_assignments.csv".format(
        score_path, method1, view, KCC_space
    ),
    index_col=0,
)
if method == "DBSCAN":
    assignment1["assignment"] = assignment1["assignment"] + 1
    assignment1 = assignment1[assignment1["assignment"] != 0]

# %%
assignment1[assignment1["assignment"] != 0]
# Out:
#            assignment
# sample.id
# BE-003              1
# BE-004              2
# BE-005              1
# BE-007              1
# BE-008              2
# ...               ...
# ZH-244              3
# ZH-246              2
# ZH-255              3
# ZH-257              1
# ZH-259              1
#
# [276 rows x 1 columns]

# %% [markdown]
# # cluster characteristics

# %%
configs = [
    ["clinical", 4, "ConsensusKMeans"],
    ["contextual", 5, "ConsensusKMeans"],
    ["physio", 3, "DBSCAN"],
    ["proteome", 3, "ConsensusKMeans"],
    ["proteome", 4, "ConsensusKMeans"],
]
for i in range(len(configs)):
    view, KCC_space, method = configs[i]
    
    assignment = pd.read_csv(
        "{}/{}_{}_view_KCC_{}_assignments.csv".format(
            score_path, method, view, KCC_space
        ),
        index_col=0,
    )
    if method == "DBSCAN":
        assignment["assignment"] = assignment["assignment"] + 1
        assignment = assignment[assignment["assignment"] != 1]
    assignment['assignment'] = assignment['assignment'].astype(int)
    print('{} view, KCC {}, {}'.format(*configs[i]))
    get_characteristic(clinical_view, assignment)
    print("-" * 80)
# Out:
# clinical view, KCC 4, ConsensusKMeans
# cluster              1         2      3         4   overall
# cons05.resp      0.013     0.233   0.96     0.148     0.222
# cons05.cvs       0.069     0.086   0.56     0.197     0.158
# cons05.cns       0.019     0.078    0.4     0.049      0.09
# cons05.ren       0.013     0.034   0.12     0.016     0.034
# cons05.hep       0.062     0.043   0.14     0.115     0.075
# cons05.hem       0.175     0.069   0.32     0.393     0.196
# cons05.score      0.35     0.543    2.5     0.918     0.775
# ccc.summary      0.631     0.509   1.26     1.361     0.791
# age.at.bc     1783.931  1100.784  586.8  1594.934  1394.705
# sex              0.606     0.647   0.64     0.623     0.625
# death.30.bc      0.019     0.009   0.18     0.033     0.039
# picu             0.287     0.388   0.98     0.311     0.411
# size               160       116     50        61       387
# --------------------------------------------------------------------------------
# contextual view, KCC 5, ConsensusKMeans
# cluster             1         2       3         4         5   overall
# cons05.resp     0.231     0.062   0.023     0.419     0.256     0.222
# cons05.cvs      0.209     0.012   0.045     0.118     0.359     0.158
# cons05.cns      0.066     0.049     0.0     0.086     0.218      0.09
# cons05.ren      0.022       0.0   0.068     0.065     0.026     0.034
# cons05.hep      0.088     0.025   0.045     0.086     0.115     0.075
# cons05.hem      0.176     0.062     0.0      0.28     0.372     0.196
# cons05.score    0.791      0.21   0.182     1.054     1.346     0.775
# ccc.summary       1.0     0.333   0.295     1.043       1.0     0.791
# age.at.bc     807.286  2296.457  670.25  1215.495  1765.936  1394.705
# sex             0.626      0.58   0.705     0.602     0.654     0.625
# death.30.bc     0.044     0.012   0.023     0.032     0.077     0.039
# picu            0.516     0.173   0.114     0.473     0.628     0.411
# size               91        81      44        93        78       387
# --------------------------------------------------------------------------------
# physio view, KCC 3, DBSCAN
# cluster            0.0      2.0       3.0      4.0   overall
# cons05.resp      0.316     0.04     0.099    0.941     0.222
# cons05.cvs       0.158    0.024     0.136    0.529     0.158
# cons05.cns       0.053    0.008     0.025    0.412      0.09
# cons05.ren         0.0    0.008       0.0    0.137     0.034
# cons05.hep       0.053     0.04      0.16    0.098     0.075
# cons05.hem       0.158    0.056     0.556    0.235     0.196
# cons05.score     0.737    0.176     0.975    2.353     0.775
# ccc.summary        1.0    0.432     1.358    1.157     0.791
# age.at.bc     1569.263  1830.84  1840.333  582.647  1394.705
# sex              0.316    0.688      0.58    0.647     0.625
# death.30.bc        0.0      0.0     0.049    0.176     0.039
# picu             0.526    0.184     0.309     0.98     0.411
# size                19      125        81       51       387
# --------------------------------------------------------------------------------
# proteome view, KCC 3, ConsensusKMeans
# cluster              1       2       3   overall
# cons05.resp      0.186   0.137    0.39     0.222
# cons05.cvs       0.128   0.115    0.26     0.158
# cons05.cns       0.045   0.069    0.19      0.09
# cons05.ren       0.038   0.015    0.05     0.034
# cons05.hep       0.109   0.023    0.09     0.075
# cons05.hem       0.314   0.053     0.2     0.196
# cons05.score     0.821   0.412    1.18     0.775
# ccc.summary      0.737    0.71    0.98     0.791
# age.at.bc     1672.667  1365.0  1000.0  1394.705
# sex              0.622   0.641    0.61     0.625
# death.30.bc      0.032     0.0     0.1     0.039
# picu             0.333   0.351    0.61     0.411
# size               156     131     100       387
# --------------------------------------------------------------------------------
# proteome view, KCC 4, ConsensusKMeans
# cluster            1        2         3         4   overall
# cons05.resp    0.297    0.158     0.337      0.09     0.222
# cons05.cvs     0.132    0.142     0.235     0.115     0.158
# cons05.cns     0.066    0.083     0.163     0.038      0.09
# cons05.ren     0.044    0.008     0.071     0.013     0.034
# cons05.hep     0.066    0.025     0.071     0.167     0.075
# cons05.hem      0.11     0.05     0.173     0.551     0.196
# cons05.score   0.714    0.467     1.051     0.974     0.775
# ccc.summary    0.659    0.758     0.888     0.872     0.791
# age.at.bc     1060.0  1234.05  1167.449  2317.885  1394.705
# sex            0.637    0.608     0.643     0.615     0.625
# death.30.bc    0.022      0.0     0.071     0.077     0.039
# picu           0.451    0.375     0.582     0.205     0.411
# size              91      120        98        78       387
# --------------------------------------------------------------------------------
